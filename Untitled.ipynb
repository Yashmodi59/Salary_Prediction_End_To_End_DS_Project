# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("diabetes.csv").iloc[:,1:]
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   SkinThickness             768 non-null    int64
#  3   Insulin                   768 non-null    int64
#  4   BMI                       768 non-null    float64
#  5   DiabetesPedigreeFunction  768 non-null    float64
#  6   Age                       768 non-null    int64
#  7   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %%
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(dpi=120)
sns.set_palette("coolwarm")
sns.histplot(data=df, x='Age', bins=30)
plt.show()

# %%
plt.figure(dpi=120)
sns.set_palette("inferno")
sns.countplot(x='Outcome', data=df)
plt.ylabel("Quantidade")
plt.show()

# %%
plt.figure(dpi=130)
sns.set_palette("Set1")
sns.scatterplot(y='Glucose', x='BMI', hue='Outcome', data=df)
plt.show()

# %%
plt.figure(dpi=120)
sns.set_palette("PuBuGn_r")
sns.scatterplot(y='Age', x='BloodPressure', data=df)
plt.show()

# %%
df[["Glucose","Outcome"]].groupby("Outcome").mean().sort_values(by="Glucose", ascending=False)
# Out:
#             Glucose
# Outcome
# 1        141.257463
# 0        109.980000

# %%
df[["Insulin","Outcome"]].groupby("Outcome").mean().sort_values(by="Insulin", ascending=False)
# Out:
#             Insulin
# Outcome
# 1        100.335821
# 0         68.792000

# %%
df[["SkinThickness","Outcome"]].groupby("Outcome").mean().sort_values(by="SkinThickness", ascending=False)
# Out:
#          SkinThickness
# Outcome
# 1            22.164179
# 0            19.664000

# %%
df[["BloodPressure","Outcome"]].groupby("Outcome").mean().sort_values(by="BloodPressure", ascending=False)
# Out:
#          BloodPressure
# Outcome
# 1            70.824627
# 0            68.184000

# %%
df[["BMI","Outcome"]].groupby("Outcome").mean().sort_values(by="BMI", ascending=False)
# Out:
#                BMI
# Outcome
# 1        35.142537
# 0        30.304200

# %%
plt.figure(dpi=110)
sns.heatmap(df.corr(), annot=True, cmap="Blues")
plt.show()

# %%
X = df.drop("Outcome", axis=1)
y = df['Outcome']

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, recall_score, f1_score, precision_score, accuracy_score

# %% [markdown]
# ## Instanciando modelos

# %%
adamodel = AdaBoostClassifier()
gradmodel = GradientBoostingClassifier()
logmodel = LogisticRegression()
rfmodel = RandomForestClassifier()
svcmodel = SVC()
extmodel = ExtraTreesClassifier()

# %% [markdown]
# ## Treinando Modelos

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.30, random_state=46)

# %%
adamodel.fit(Xtrain, ytrain)
gradmodel.fit(Xtrain, ytrain)
logmodel.fit(Xtrain, ytrain)
rfmodel.fit(Xtrain, ytrain)
svcmodel.fit(Xtrain, ytrain)
extmodel.fit(Xtrain, ytrain)
# Out:
# ExtraTreesClassifier()

# %% [markdown]
# ## Armazenando predições

# %%
adapred = adamodel.predict(Xtest)
gradpred = gradmodel.predict(Xtest)
logpred = logmodel.predict(Xtest)
rfpred = rfmodel.predict(Xtest)
svcpred = svcmodel.predict(Xtest)
extpred = extmodel.predict(Xtest)

# %% [markdown]
# ## Armazenando Métricas gerais(acurácia, revocação, precisão e F1-score)

# %%
scores = np.array([adapred, gradpred, logpred, rfpred, svcpred, extpred])
precision = []
recall = []
f1 = []
accuracy = []
for i in scores:
    accuracy.append(accuracy_score(ytest, i)*100)
    precision.append(precision_score(ytest, i)*100)
    recall.append(recall_score(ytest, i)*100)
    f1.append(f1_score(ytest, i)*100)

# %%
modelos = "Adaboost GradientBoosting LogisticRegression RandomForest SVC ExtraTree".split()
metricasGerais = pd.DataFrame({
        "Models":modelos,
        "Accuracy":accuracy,
        "Precission":precision,
        "Recall":recall,
        "F1":f1
             }).sort_values(by="Recall",ascending=False)

# %% [markdown]
# ## Exibindo ranking de modelos

# %%
metricasGerais
# Out:
#                Models   Accuracy  Precission  Recall         F1
# 1    GradientBoosting  74.025974   60.638298   71.25  65.517241
# 3        RandomForest  74.025974   60.869565   70.00  65.116279
# 5           ExtraTree  76.623377   65.116279   70.00  67.469880
# 0            Adaboost  72.294372   58.695652   67.50  62.790698
# 2  LogisticRegression  79.220779   72.857143   63.75  68.000000
# 4                 SVC  77.489177   73.333333   55.00  62.857143

# %% [markdown]
# Obs:Neste caso, **priorizando a revocação**, Gradient Boosting obteve o melhor resultado

# %% [markdown]
# ## Melhorando performance do modelo com melhor desempenho

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Selecionando parametros

# %%
params = {
    'n_estimators':[100,200,300,400,500],
    'min_samples_leaf':[1,2,3],
    'max_depth':[1,2,3]
}

# %%
grid = GridSearchCV(GradientBoostingClassifier(random_state=46), param_grid=params)

# %% [markdown]
# ### Executando treino do modelo escolhido com todos os parametros

# %%
grid.fit(X, y)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(random_state=46),
#              param_grid={'max_depth': [1, 2, 3], 'min_samples_leaf': [1, 2, 3],
#                          'n_estimators': [100, 200, 300, 400, 500]})

# %% [markdown]
# ### Melhores parametros encontrados durante o treino

# %%
grid.best_params_
# Out:
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 300}

# %% [markdown]
# ### Armazenando as novas predições

# %%
gridpred = grid.predict(Xtest)

# %% [markdown]
# ### Passando o novo resultado das métricas para um novo dataframe

# %%
modeloFinal = pd.DataFrame({
    "Model Name":"Gradient Boosting",
    "Accuracy":[accuracy_score(ytest, gridpred)*100],
    "Precission":[precision_score(ytest, gridpred)*100],
    "Recall":[recall_score(ytest, gridpred)*100],
    "F1":[f1_score(ytest, gridpred)*100]
})

# %% [markdown]
# ## Modelo antes do Tuning

# %%
metricasGerais[metricasGerais["Models"] == "GradientBoosting"]
# Out:
#              Models   Accuracy  Precission  Recall         F1
# 1  GradientBoosting  74.025974   60.638298   71.25  65.517241

# %% [markdown]
# ## Modelo após Tuning

# %%
modeloFinal
# Out:
#           Model Name   Accuracy  Precission  Recall         F1
# 0  Gradient Boosting  81.818182   75.675676    70.0  72.727273

# %% [markdown]
# # Conclusão
# Apesar do modelo SVC ter apresentado uma melhor acurácia e precisão, por se tratar de uma classificação de doença, a prioridade é minimizar ao máximo os falsos negativos(ter a doença, e nao acusar), e o modelo Gradient Boosting obteve o melhor score de revocação, sendo a melhor opção para este caso

# %%
X = df.drop("Outcome", axis=1)
y = df['Outcome']
